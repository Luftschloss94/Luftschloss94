# %%
#Game Theory - Fernando Gamboa 
#Notes, for the No option you need to control response and use a loop so the computer plays vs itself 
#General Description 
Story = """"Two Formula 1 Pilots within the Redbull team, Sergio 'Checo' Perez and Player 1 
are competing in the Round 20 of the Mexican Grand Prix. Both pilots are competing for the 1st place in the podium.
However, both cannot win, currently Checo has 18 points and Player_1 18 points as well. As a pilot you have the following options: 
A) Both Checo and Player 1 can cooperate and both to pass into the next round. Finishing Player 1 in 1st and Checo in 2nd. 
B) If Checo wins, he can achieve 1st place. But Max would be disqualified into next round. 
C) If Player 1 wins, he can achieve 1st place. But Checo would be disqualified into next round.
D) If they don't cooperate and work together they both are disqualified 
"""

A = "Both Checo and Player 1 can cooperate and both to pass into the next round."
B = "If Checo wins, he can achieve 1st place. But Max would be disqualified into next round." 
C = "If Player 1 wins, he can achieve 1st place. But Checo would be disqualified into next round."
D = "If they don't cooperate and work together they both are disqualified "

#We Import the random package 

import random 

user_play = ''

#To start the game, user must agree 

user_selection = ["yes","no"]

while user_play not in user_selection:
    user_play = input("Would you like to be a pilot for the RedBull F1 Team? (yes/no) ").lower()
    
    
#User agrees to play the game
#For first if with "yes" 

if "yes" in user_play: 
    user_name = input("\n Hi, and welcome to Formula 1 Simulator! You will race against me! Whats your name? ").capitalize()
    print(f"\n {user_name}, time to race! You and Sergio 'Checo' Perez are competing each other to qualify into the next round.\n Ready! Set! Go!") 

    
    #Game introduction  
    print("""\n You are located in the Mexico City GP, Checo and you have 18 points, you need at least 2 points to qualify
    for the next round.The team strategist approaches to you: """)

    print(f"""
    Team Strategist: {user_name}, we need one of you guys to make it into the next round, cooperate to win 2 points each.
    Let Checo have the first place since he has better timing. Look at the options:
    \n 
    {user_name} \ Checo \t\t\t Cooperate and let Checo Win \t\t No cooperation 
    ------------------- \t\t ------------------------------\t\t -------------------     
    Cooperate with Checo\t\tBoth players are qualified\t\tCheco wins 1st place. {user_name} is disqualified
    No Cooperation \t\t {user_name} wins 1st place.Checo is disqualified \t Both are disqualified    

    """)

    #Boardgame with pay-off matrix 
    board_game = [[3,1], [2,0]]

    #Create dictionary with points according to each outcome. C:Cooperate , NC: No Cooperation
    dictionary_results = {"(C, C)": (board_game[0][0], board_game[0][0]),
                          "(C, NC)": (board_game[0][1], board_game[1][0]),
                          "(NC, C)": (board_game[1][0], board_game[0][1]),
                          "(NC, NC)": (board_game[1][1], board_game[1][1])}
   
    #Query to start the loop 
    accumulated = 0
    accumulated_computer = 0
    for i in range(5):
        
    #User selection on game's choices 
        user_choose = ''
        user_answer = ['C','NC']
        
        while user_choose not in user_answer: 
            user_choose = input("""
    What would you do? Are you going to play as a team or take all the glory for yourself?
    Select:
    - 'C' to Cooperate and let Checo win
    - 'NC' to Not cooperate and win for yourself
    """).upper()
            if user_choose not in user_answer:
                print("\nPlease, select a valid answer")
    
    #Checo Perez random choice generator between cooperating with player or winning for himself 
        computer_choose = random.randint(0,1) # 0: Cooperate; 1: Win for yourself

    #conditional structure with the outputs of each scenario
        if user_choose == "C" and computer_choose == 0:
            user_result = dictionary_results["(C, C)"][0]
            computer_result = dictionary_results["(C, C)"][0]
            print(f"""
    You've decided to be a team player, as well as me!
    You earned {user_result} points.
    I earned {computer_result}""")
    
        elif user_choose == "NC" and computer_choose == 0:
            user_result = dictionary_results["(NC, C)"][1]
            computer_result = dictionary_results["(NC, C)"][0]
            print(f"""
    You've decided to win, I am disqualified!
    You earned {user_result} points.
    I earned {computer_result}""")

        elif user_choose == "C" and computer_choose == 1:
            user_result = dictionary_results["(C, NC)"][0]
            computer_result = dictionary_results["(C, NC)"][1]
            print(f"""
    Checo got greedy, I am disqualified!
    You earned {user_result} points.
    I earned {computer_result}""")

        elif user_choose == "NC" and computer_choose == 1:
            user_result = dictionary_results["(NC, NC)"][1]
            computer_result = dictionary_results["(NC, NC)"][1]
            print(f"""
    We wanted the 1st place and lost, we both are disqualified
    You earned {user_result} points.
    I earned {computer_result}""")

# Declaring a winner.

        accumulated += user_result
        accumulated_computer += computer_result

        
        if accumulated > accumulated_computer:
            print(f""" \n Final Player Score {accumulated}""")
            print(f"""Final Computer Score {accumulated_computer}""")
            print(f"""Congrats {user_name}, you qualified!""")

        elif accumulated == accumulated_computer:
            print(f""" \n Final {user_name} Score {accumulated}""")
            print(f"""Final Computer Score {accumulated_computer}""")
            print("""We both qualified!""")

        elif accumulated <= accumulated_computer:
            print(f""" \n Final {user_name} Score {accumulated}""")
            print(f"""Final Computer Score {accumulated_computer}""")
            print("""Congrats to me, I qualified!""") 
    
#Here we start the coding for Computer vs Computer 
#Introduction-Start Screen 

else: 
    if "no" in user_play:
        print("\n Hi, and welcome to Formula 1 Simulator! Max Verstappen vs Sergio 'Checo' Perez! ")
        print("\n Time to race! Max and Checo are competing each other to qualify into the next round.\n Ready! Set! Go!")
        
#Introduction-Stortyline 

        print("""\n Pilots are located in the Mexico City GP, Checo and Max have 18 points, they need at least 2 points to qualify
    for the next round.The team strategist approaches: """)

        print("""
    Team Strategist: We need one of you guys to make it into the next round, cooperate to win 2 points each.
    Let Checo have the first place since he has better timing. Look at the options:
    \n 
    Max \ Checo \t\t\t Cooperate and let Checo Win \t\t No cooperation 
    ------------------- \t\t ------------------------------\t\t -------------------     
    Cooperate with Checo\t\tBoth players are qualified\tCheco wins 1st place. Max is disqualified
    No Cooperation \t\t Max wins 1st place.Checo is disqualified \t Both are disqualified    

    """)
           
    
    #Boardgame with pay-off matrix 
    board_game = [[3,1], [2,0]]
    
    #Create dictionary with points according to each outcome. C:Cooperate , NC: No Cooperation
    dictionary_results = {"(C, C)": (board_game[0][0], board_game[0][0]),
                          "(C, NC)": (board_game[0][1], board_game[1][0]),
                          "(NC, C)": (board_game[1][0], board_game[0][1]),
                          "(NC, NC)": (board_game[1][1], board_game[1][1])}
    
    #Query to start the looping
    score_of_max = 0
    score_of_checo = 0
    for i in range(5): 
    
    #Random choice generator between cooperating or winning 
        computer_choose_m = random.randint(0,1) # 0: Cooperate; 1: Win for yourself
    
    #Second computer choice, generates random number from predetermined list 
        my_list = [0]*20 + [1]*20 
        random_list = random.shuffle(my_list)
        computer_choose_c = random.choice(my_list)
            
    #conditional structure with the outputs of each scenario
        if computer_choose_m == 0 and computer_choose_c == 0:
            user_result = dictionary_results["(C, C)"][0]
            computer_result = dictionary_results["(C, C)"][0]
            print(f"""
    Pilots decided to be team players!
    Max earned {user_result} points.
    Checo earned {computer_result}""")
        
        elif computer_choose_m == 0 and computer_choose_c == 1:
            user_result = dictionary_results["(C, NC)"][0]
            computer_result = dictionary_results["(C, NC)"][1]
            print(f"""
    Checo decided to win, Max is disqualified!
    Max earned {user_result} points.
    Checo earned {computer_result}""")
    
        elif computer_choose_m == 1 and computer_choose_c == 0:
            user_result = dictionary_results["(NC, C)"][1]
            computer_result = dictionary_results["(NC, C)"][0]
            print(f"""
    Max decided to win, Checo is disqualified!
    Max earned {user_result} points.
    Checo earned {computer_result}""")
   
        elif computer_choose_m == 1 and computer_choose_c == 1:
            user_result = dictionary_results["(NC, NC)"][1]
            computer_result = dictionary_results["(NC, NC)"][1]
            print(f"""
    Both pilots wanted 1st place and lost, both are disqualified
    Max earned {user_result} points.
    Checo earned {computer_result}""")
    
    # Declaring a winner.
    
        score_of_max += user_result
        score_of_checo += computer_result

        if score_of_max > score_of_checo:
            print(f""" \n Final Max's Score {score_of_max}""")
            print(f""" Final Checo's Score {score_of_checo}""")
            print(f"""Congrats to Max, he qualified!""")

        elif score_of_max == score_of_checo:
            print(f""" \n Final Max's Score {score_of_max}""")
            print(f""" Final Checo's Score {score_of_checo}""")
            print(f"""We are qualified!""")

        elif score_of_max <= score_of_checo:
            print(f""" \n Final Max's Score {score_of_max}""")      
            print(f""" Final Checo's Score {score_of_checo}""")
            print(f"""Congrats to Checo, he qualified!""")
# Out:
# Would you like to be a pilot for the RedBull F1 Team? (yes/no) no
#
#  Hi, and welcome to Formula 1 Simulator! Max Verstappen vs Sergio 'Checo' Perez!
#
#  Time to race! Max and Checo are competing each other to qualify into the next round.
#  Ready! Set! Go!
#
#  Pilots are located in the Mexico City GP, Checo and Max have 18 points, they need at least 2 points to qualify
#     for the next round.The team strategist approaches:
#
#     Team Strategist: We need one of you guys to make it into the next round, cooperate to win 2 points each.
#     Let Checo have the first place since he has better timing. Look at the options:
#
#
#     Max \ Checo 			 Cooperate and let Checo Win 		 No cooperation
#     ------------------- 		 ------------------------------		 -------------------
#     Cooperate with Checo		Both players are qualified	Checo wins 1st place. Max is disqualified
#     No Cooperation 		 Max wins 1st place.Checo is disqualified 	 Both are disqualified
#
#
#
# ...

# %%
#Your program must have the following:
#* A full description of the game theory situation (No more than 250 words) 
#* A python print table that presents the possible outcomes for all combinations (similar to figure 1) 
#* A dictionary with points (value) assigned to each possible outcome.- done 
#* At least one nested conditional.
#* Ask the user if they want to play the game or not
#    * If yes, program will run a game between Python and the user. (I.e., user and Python must choose if cooperate or defect) 
#   * If no, program will run a game between 2 Python players. (I.e., two "Python players" must choose if cooperate or defect)
#* The program must control any incorrect input from the user (hint: Use conditional and loop statements). - pending loop 
#* The strategy/decision making process of the 2 "Python players" must be different (I.e., if one python user randomly selects to cooperate or not, the second computer must use a different strategy to decide whether to cooperate or not.) 
#* Run the program between 2 Python players 5 times (hint: use loops). Save the results of each round and declare a winner.
#* Final statement declaring the winner
