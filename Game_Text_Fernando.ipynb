# %%
"""
Fernando Gamboa 
"""
"""
    DocString (131 words):
    
    Game Introduction:
    
    The game is based on the The Star Wars spin-off: The Clone Wars Series (2008-2020).
    You are Anakin Skywalker, commander of the 501st clone legion during the war between the Republic
    and the Separatists. Currently, Anakin and Captain Rex are undergoing a siege on the forest-like 
    planet of Umbara. 
    
    Round 1: Determine your landing zone
    Round 2: Head to the enemy's city. Could be into forest, investigate downed aircraft or direct route. 
    Round 3: Decide how to infiltrate the enemy city 
    Round 4: Once in the enemy HQ decide how to climb up until last floor
    Round 5: Final fight against the final boss, Count Dooku 
    
    B) Known Bugs and/or Errors:
    1) Sometimes entry() function at the beginning won't move the game to stage 1 
    - Status: Solved by moving the entry() command at the end of the code. 
    
"""

#Introduction the purpose of this section is to introduce the player into the game
#We import sys function from exit package to create fail function
#Import random for action scene, which may vary 

from sys import exit 
import random 

#This input prompts the player to add his name and explain game instructions
# " \033[1m 'text' \033[0m " is bolding the text 

player_name = input("""\n Welcome Master Jedi to the 501st under the command of General Skywalker!
Please register your name: """).title()
print(f""" \n \033[1mIn a Galaxy Far Far Away...    
\n War! The Republic is crumbling under attacks 
by the ruthless Sith Lord,Count Dooku. 
Our heroes {player_name} and Anakin Skywalker
are leading a campaign against 
the key separatist world in Umbara...\033[0m """)

print("""\n Instructions: Type a, b or c to select your player choice in each situation. """)

input("<Press enter to start the game>")


#Start of stage 1 

## Define function for entry stage
def entry():
    print(""" 
    -------------------------------------------
    
    Stage 1 - Entry into Umbara
    
    -------------------------------------------
    """)
    print(""" \n You and the squad are entering the planet orbit with the transport shuttle. 
    Suddenly, you encounter heavy fire and your pilots ask for course of action: """)
    
    print(""" 
    a) Evasive action! Try to get us as close as possible to landing zone 
    b) Return fire! Continue into planned route
    c) Crash landing! Get us to the ground now """)

### Loop for input handling, meaning that if it is not a,b or c 
    choice = ''
    player_answer = ['a','b','c']
    
    while choice not in player_answer:
        
        choice = input(" > \n").lower()
        
        if choice not in player_answer:
            print("\n Please type a,b, or c to select answer")
            
#Here we define the choices depending on the answer. At the end, player will go to selected stage
#If player choses a it will direct player into Landing as Stage 2
    if "a" in choice:
        print("""\n We\'re hit! The shuttle crashes near landing zone, you assess damage and continue""")
        input("<Press enter to continue into Landing Zone>")
        landing()
    
    elif "b" in choice:
        print("""\n The ship has received heavy fire! Your squad has been disabled """)
        input("<Press enter to exit>")
        fail()
#If player chooses c it will direct player into The Forest as Stage 2    
    elif "c" in choice: 
        print("""\n You have avoided heavy damage. Most of your crew is intact.
              You continue through the forest""")
        input("<Press enter to continue into Forest>")
        print(""" 
    -------------------------------------------
    
    Stage 2 - The Forest
    
    -------------------------------------------
    """)
        forest()
        
#Start of stage 2 
def landing():
    print(""" 
    -------------------------------------------
    
    Stage 2 - The Landing Zone 
    
    -------------------------------------------
    """)
    print("""\n After crashing your team made it close to the landing zone. 
    You team up with Captain Rex's squad.
    Under heavy fire you plan different tactics to arrive into the enemy\'s city. """)
    print("""
    a)Forward! Through hell and fire you continue into the city
    b)You see a downed aircraft. Perhaps we can rescue friends and take cover
    c)You take the path towards the forest. Out of sight will be easier to sneak in """)
 
 ### Loop for input handling, meaning that if it is not a,b or c 

    choice = ''
    player_answer = ['a','b','c']
    
    while choice not in player_answer:
        
        choice = input(" > \n").lower()
        
        if choice not in player_answer:
            print("\n Please type a,b, or c to select answer")
   
    #Here we define the choices depending on the answer. At the end, player will go to selected stage                 
    
    #If player choses a it will direct player into the Headquarter stage as round 3
    if "a" in choice:
        print(""" You take a lot of casualties but make it into the main HQ thanks to AT-TE support""")
        input("<Press enter to continue into Headquarters>")
        headquarters()
    
    elif "b" in choice: 
        print(""" When your squad approaches the downed aircraft you discover it's a trap.""")
        input("<Press enter to continue>")
        fail()
    
    #If player choses c it will direct player into the Forest as round 3 
    elif "c" in choice: 
        print(""" The squad takes a safe route towards the forest """)
        input("<Press enter to continue into Forest>")
        print(""" 
    -------------------------------------------
    
    Stage 3 - The Forest
    
    -------------------------------------------
    """)
        forest()
    
#Stage 2 if player chooses c on "entry". If player chooses c on "landing" this is stage 3 
def forest():
    print("""\n The 501st decides to enter into the forest. 
    It is all quiet and away from the battlefield...too quiet. 
    \n You have a bad feeling about this and signal everyone to stop.""")
    print("""
    a) You signal your squad to fall in line
    b) It\'s nothing, you are sure that you can walk quietly through the forest
    c) You signal for squad formation and proceed """)
    
 ### Loop for input handling, meaning that if it is not a,b or c 
    choice = ''
    player_answer = ['a','b','c']
    
    while choice not in player_answer:
        
        choice = input(" > \n").lower()

    #Here we define the choices depending on the answer. At the end, player will go to selected stage                         
        if choice not in player_answer:
            print("\n Please type a,b, or c to select answer")
    #If player selects a it will direct player into headquarters stage 
    if "a" in choice:
        print(""" A few minutes later you notice mines, everyone is safe""")
        input("<Press enter to continue into Headquarters>")
        headquarters()
        
    elif "b" in choice: 
        print("""Your squad is wiped out by mines""")
        input("<Press enter to continue>")
        fail()
    #If player selects a it will direct player into headquarters stage
    elif "c" in choice: 
        print("""Everyone is able to notice the mines. The team makes it through """)
        input("<Press enter to continue into Headquarters>")
        headquarters()
        
#Stage 4 - define function of headquarters 
def headquarters():
    print(""" 
    -------------------------------------------
    
    Stage 4 - Headquarters
    
    -------------------------------------------
    """)
    print("""\n Siege! You managed to infiltrate into the city. 
    Anakin helps the squad to infiltrate into the headquarters. 
    As you climb the building to get into the enemy general, the squad struggles with enemy droids.""")
    print("""
    a) Climb up through the stairs and engage all enemies. 
    b) Use magnetic harpoon and climb near the last floor.
    c) Infiltrate through the sewage system and breach through the stairs. 
    """)
    
### Loop for input handling, meaning that if it is not a,b or c 

    choice = ''
    player_answer = ['a','b','c']
    
    while choice not in player_answer:
        
        choice = input(" > \n").lower()
        
        if choice not in player_answer:
            print("\n Please type a,b, or c to select answer")
            
#Here we define the choices depending on the answer. At the end, player will go to selected stage                          
    if "a" in choice:
        print(" Too many enemies! The squad couldn't advance")
        input("<Press enter to continue>")
        fail()
#If player choses b it will direct player to final stage 
    elif "b" in choice:
        print("""The squad managed to climb successfully, 
        destroy surrounding drones and enter to the control center""")
        input("""\n<Press enter to continue into Final Boss>""")
        print(""" 
    -------------------------------------------
    
    Final Boss! 
    
    -------------------------------------------
    """)
        final_boss()
    
    elif "c" in choice:
        print("Blast! The drone commander knew exactly this move. The squad is buried underground")
        input("<Press enter to continue>")
        fail()
        
#Stage 5 - define function of final boss, input for heroic line and final choices in game 
def final_boss():
    print(f"""\n Count Dooku: My fellow Jedis, Skywalker and {player_name}, 
    it is obvious that this contest cannot be won by the knowledge of the force. 
    But by our skills with the lightsaber""")
    
#Action scene where Dooku attacks after his instroduction scene 
#Action is selected from random list, and depending on conditional statement scene is selected 
    dooku_attacks = [1,2,3]

    random.shuffle(dooku_attacks)

    dooku_choice = random.choice(dooku_attacks)

    if dooku_choice == 1: 
        print(f"\n He uses the force to throw a rock into {player_name}")
        print(f"\n {player_names} skillfully uses the lightsaber and deflects the attack" )
    
    elif dooku_choice == 2:
        print(f"\n He throws an estocade directly into Anakin")
        print("\n Anakin is faster and counters the attack. All, back off")

    elif dooku_choice == 3:
        print(f"\n He uses the force to throw lightning at {player_name}")
        print(f"\n {player_names} skillfully uses the lightsaber and deflects the attack" )

                 
#Input for hero line    

    epic_response = input("\n Write your epic Jedi punch line here: \n ")
   
    print("""\n 
    a) You decide to fight in sync with Anakin
    b) The rage in you is strong, you engage alone in combat """)
   
 ### Loop for input handling, meaning that if it is not a,b or c 
    choice = ''
    player_answer = [1,2,3]
    
    while choice not in player_answer:
        
        choice = int(input(" > \n"))
        
        if choice not in player_answer:
            print("\n Please type 1, 2 or 3 to select answer")
            
#Define final game choices             
    if 1 in choice:
        print("""\n Both Jedis skillfully surround and defeat Count Dooku, 
              he activates a hidden bomb and escapes.""")
        print("\n Congratulations! The Republic has successfully taken Umbara")
        new_game()
    
    elif 2 in choice:
        print(""""Count Dooku is too skillful. He chops off Anakin's hand and you receive a direct hit. 
              Mission Failed""")
        fail()

#Fail Function - When player loses the game it will redirect them here and finish the game  

def fail():
    print(f'\n The 501st has been wiped out. {player_name} and the rest of the squad will be remembered')
    input('<Game Over> \n <Press enter for new game>')
    new_game()
        
#Restart the game, generates a loop requesting if the player wants to play
#If selected no, the game will exit from system
def new_game():
    
    again = ''
    play_again = ['yes', 'no']
    
    while again not in play_again:
        
        again = input("Would you like to play again? yes/no ").lower()
        
        if 'yes' in again:
            entry()
        
        if 'no'  in again:
            exit(0)
        
#Start game go-to function
entry()
# Out:
#  Welcome Master Jedi to the 501st under the command of General Skywalker!
# Please register your name: L
#
#  In a Galaxy Far Far Away...
#
#  War! The Republic is crumbling under attacks
# by the ruthless Sith Lord,Count Dooku.
# Our heroes L and Anakin Skywalker
# are leading a campaign against
# the key separatist world in Umbara...
#
#  Instructions: Type a, b or c to select your player choice in each situation.
# <Press enter to start the game>
#
#     -------------------------------------------
#
#     Stage 1 - Entry into Umbara
#
#     -------------------------------------------
#
#
#  You and the squad are entering the planet orbit with the transport shuttle.
#     Suddenly, you encounter heavy fire and your pilots ask for course of action:
#
#     a) Evasive action! Try to get us as close as possible to landing zone
#     b) Return fire! Continue into planned route
#     c) Crash landing! Get us to the ground now
#  >
# a
#
# ...
